# %% [markdown]
# # Data Preprocessing

# %%
# Importing the required modules and libraries
import pandas as pd

# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"/utils")

from spotify_client import spotify

# %%
raw_80s_df = pd.read_csv('../data/raw/tracks_80s.csv')
raw_90s_df = pd.read_csv('../data/raw/tracks_90s.csv')
raw_00s_df = pd.read_csv('../data/raw/tracks_00s.csv')
raw_10s_df = pd.read_csv('../data/raw/tracks_10s.csv')

raw_data_df = pd.concat([raw_80s_df, raw_90s_df, raw_00s_df, raw_10s_df], ignore_index=True, axis=0)

del raw_80s_df, raw_90s_df, raw_00s_df, raw_10s_df

raw_data_df.shape
# Out:
# (24698, 19)

# %%
song_uri_list = raw_data_df.uri.tolist()

# %%
def get_tracks_metadeta(song_uri_list):
    albums = []
    release_types = []
    release_dates = []
    explicities = []
    popularities = []
    artists = []
    
    num_iters = len(song_uri_list) // 50
    
    for iter in range(num_iters+1):
        # print(iter)
        if iter == 0:
            starting_index = 0
            ending_index = 50
        else:
            starting_index = ending_index
            ending_index += 50
        
        if iter != num_iters:
            response = spotify.tracks(tracks=song_uri_list[starting_index:ending_index])
        else:
            response = spotify.tracks(tracks=song_uri_list[starting_index:])
            
        tracks = response['tracks']
        
        for track in tracks:
            albums.append(track['album']['name'])
            release_types.append(track['album']['album_type'])
            release_dates.append((track['album']['release_date'], track['album']['release_date_precision']))
            explicities.append(True if track['explicit'] == 'true' else False)
            popularities.append(track['popularity'])
            artist_list = []
            
            for artist in track['artists']:
                artist_list.append(artist['name'])
                
            artists.append(artist_list)
        
    return albums, release_types, release_dates, explicities, popularities, artists

# %%
albums, release_types, release_dates, explicities, popularities, artists = get_tracks_metadeta(song_uri_list)

# %%
artists_str_list = []

for artist in artists:
    artist_str = ''
    for unit in artist:
        artist_name = unit.replace('"','')
        artist_str += f'{artist_name}&&'
    
    artist_str = artist_str.rstrip('&&')
    artists_str_list.append(artist_str)
    
artists_str_list
# Out:
# ['Big Joe Williams',
#  'The Motels',
#  "Béla Fleck&&Sam Bush&&Jerry Douglas&&Mark O'Connor&&Tony Rice&&Mark Schatz",
#  'The Pogues',
#  'John Schneider',
#  'Fields Of The Nephilim',
#  'Brighton Rock',
#  'The Other Ones',
#  'Rupert Holmes',
#  'Yngwie Malmsteen',
#  'Breakfast Club',
#  'Chris & Cosey',
#  'Orchestra Baobab',
#  'Martika',
#  'The Jets',
#  'Harold Budd&&Brian Eno',
#  'ZZ Top',
#  'Norman Blake&&Tony Rice',
#  'Running Wild',
#  'Carlos Cano',
#  'Bruce Springsteen',
#  'Eric B. & Rakim',
#  'Slime',
#  'Phil Seymour',
#  'Enya',
#  'Real Life',
#  'Moebius&&Plank',
#  'Simply Red',
#  'Big Country',
#  'Kenny Loggins',
#  'Barbra Streisand&&Donna Summer',
#  'Sheena Easton',
#  'Skinny Puppy',
#  'Huey Lewis & The News',
#  'Vladimir Cosma',
#  'Kool & The Gang',
#  'Tenor Fly&&Daddy Freddy',
#  'Demented Are Go',
#  'Skinny Puppy',
#  'Crass',
#  'Los Suaves',
#  'Keith Mansfield',
#  'The Doobie Brothers',
#  'Luiz Henrique',
#  'The Pogues',
#  'Miami Sound Machine',
#  'Paula Abdul',
#  'Stan Getz&&João Gilberto&&Antônio Carlos Jobim',
#  'George Michael',
#  'Cocteau Twins',
#  'The Fixx',
#  'Jody Watley',
#  'Royal House',
#  'The Alan Parsons Project',
#  'Stars On 45',
#  'Sisters of Mercy',
#  'Arthur Russell',
#  'The Robert Cray Band',
#  'Matthew Young',
#  'Spider',
#  'The Whispers',
#  'Sharon Bryant',
#  'Terry Lewis and Wild Flower',
#  'Klymaxx',
#  'Kim Carnes',
#  'Supertramp',
#  'Skinny Puppy',
#  'The Cover Girls',
#  'Weird Al Yankovic',
#  'Lucinda Williams',
#  '2 LIVE CREW',
#  'Carlos Cano',
#  'ICEHOUSE',
#  'José Alfredo Jimenez',
#  'The Suicide Twins',
#  'Ratt',
#  'Cutting Crew',
#  'Gérard Lenorman',
#  'Men At Work',
#  'Pseudo Echo',
#  'DeBarge',
#  'The Bats',
#  'Moebius&&Plank',
#  'Ray, Goodman & Brown',
#  'Four Tops',
#  'Don Henley',
#  'John Cafferty & the Beaver Brown Band',
#  'Leif Garrett',
#  'Junkyard Band',
#  'Savoy Brown',
#  'Dolly Parton',
#  'Paul Hindemith&&San Francisco Symphony&&Herbert Blomstedt',
#  'Eric B. & Rakim',
#  'EPMD',
#  'Red Rockers',
#  'Rod Stewart',
#  'Roedelius',
#  'Fugazi',
#  'Dan Fogelberg',
#  'Psychic TV',
#  'Little River Band',
#  'Anne Murray',
#  'Player',
#  'Heart',
#  'Slime',
#  'Talat Aziz',
#  'Joaquín Sabina',
#  'Bruce Willis',
#  'Starpoint',
#  'Dmitri Shostakovich&&I Musici de Montréal&&Maxim Shostakovich',
#  'Pauline Oliveros&&Stuart Dempster&&Panaiotis',
#  'Hal Singer',
#  'Pat Benatar',
#  'Barbra Streisand',
#  'Sisters of Mercy',
#  'Robbie Nevil',
#  'Randy Travis',
#  'Bee Gees',
#  'John Carpenter',
#  'Otis Spann',
#  'Billy Idol',
#  'Óscar Chávez',
#  'Peter Gabriel',
#  'Kenny Rogers',
#  'Beat Happening',
#  'Um Toque a Mais',
#  'Yarbrough & Peoples',
#  'Mr. Fingers',
#  'Eric Clapton',
#  'Marc Lavoine',
#  'Wham!',
#  'bel canto',
#  'Hüsker Dü',
#  'The Bluegrass Album Band',
#  'Van Halen',
#  'Phyllis Nelson',
#  'Kool & The Gang',
#  'Ricky Skaggs',
#  'Jovelina Perola Negra',
#  'Paul McCartney',
#  'John Parr',
#  'Little River Band',
#  'Tony MacAlpine',
#  'Malcolm Arnold&&Vernon Handley&&Nicholas Daniel&&Bournemouth Symphony',
#  'Joni Mitchell',
#  'Rick James&&Smokey Robinson',
#  'Eye To Eye',
#  'Barbra Streisand',
#  'Aries Vigoth',
#  'Los Bukis',
#  'The Cramps',
#  'Further Seems Forever',
#  'Tommy James',
#  'Sonny Terry&&Brownie McGhee',
#  'Gene Ammons',
#  'Lio',
#  'Brighton Rock',
#  'Ratt',
#  'Michael Bolton',
#  'Slime',
#  '808 State',
#  'Mick Jagger',
#  'Johnny Clegg&&Savuka',
#  'José Guardiola',
#  'Death In June',
#  'The Reddings',
#  'Shooting Star',
#  'Bee Gees',
#  'Demolition Man',
#  'The DIllman Band',
#  'Willie Nelson',
#  'Arthur Russell',
#  'Boz Scaggs',
#  'Andy Clark',
#  'Ricky Skaggs',
#  'Clan of Xymox',
#  'The Crusaders&&Joe Cocker',
#  'Stevie Wonder',
#  'Todd Rundgren',
#  'Kenny Loggins',
#  'Louisiana Red&&Odie Payne&&Robert Stroger&&Carey Bell&&Sunnyland Slim&&Hubert Sumlin',
#  'Beat Happening',
#  'Rocío Dúrcal',
#  'Queen',
#  'Fist',
#  'George Harrison',
#  'Rick Springfield',
#  'The Cars',
#  'Glass Moon',
#  'Luis Enrique',
#  'The Cleaners From Venus',
#  'Violent Femmes',
#  "Robert Palmer&&Eric 'ET' Thorngren",
#  'Kool & The Gang',
#  'Stryper',
#  'The Sugarhill Gang',
#  'Pink Anderson',
#  'Duran Duran',
#  'Luis Enrique',
#  'The Clark Sisters',
#  'Anup Jalota',
#  'Tito Rodriguez',
#  'Strength In Numbers',
#  'Elaine Machado',
#  'John Barry',
#  'Slime',
#  'Arthur Russell',
#  'Def Leppard',
#  'Heavy D & The Boyz',
#  'Danny Elfman',
#  'Mr. Mister',
#  'Eric B. & Rakim',
#  'Phil Collins',
#  'The Cleaners From Venus',
#  'Nat Adderley&&Keith Jarrett&&Gary Peacock&&Jack DeJohnette',
#  'Kishore Kumar&&Lata Mangeshkar&&R. D. Burman',
#  'Shalamar',
#  'Diana Ross',
#  'Doctor Ice',
#  'Grandmaster Flash&&The Furious Five&&The Sugarhill Gang',
#  'Chuckii Booker',
#  'Andy Clark',
#  'Gyedu-Blay Ambolley',
#  'Jimmy Buffett',
#  'Talking Heads',
#  'Belinda Carlisle',
#  'Tenor Fly',
#  'Carlos Cano',
#  'Dinosaur Jr.',
#  'Fugazi',
#  'The Doobie Brothers',
#  'Minutemen',
#  "Flamin' Groovies",
#  'Boytronic',
#  'Zohar Argov',
#  'Philip Glass&&Philip Glass Ensemble&&Michael Riesman',
#  'Rick Springfield',
#  'Regina Belle',
#  'Palabra en Acción',
#  'Stan Getz&&Luiz Bonfá',
#  'Lulu Santos',
#  "Los Yonic's",
#  'Dead Can Dance',
#  'Manowar',
#  'Fast Eddie',
#  'Opus',
#  'Roedelius',
#  'Helstar',
#  'Pagan Altar',
#  'Laurie Anderson',
#  'Skinny Puppy',
#  'Olivia Newton-John',
#  'Maurice Jarre',
#  'Éric Serra',
#  'Last Rites',
#  'Alice Cooper',
#  'Dwarves',
#  'The Motels',
#  'The Monkees',
#  '808 State',
#  'Jeffrey Osborne',
#  'Lucinda Williams',
#  'Diana Ross',
#  'Dutch Swing College Band',
#  'Martin Gore',
#  'Ali Farka Touré',
#  'Madonna',
#  'Slime',
#  '2 LIVE CREW',
#  'Paul Hindemith&&San Francisco Symphony&&Herbert Blomstedt',
#  'Smokey Robinson',
#  'ABBA',
#  'Beat Happening',
#  'Journey',
#  'Slime',
#  'Dion',
#  'Robbie Patton',
#  'Kool & The Gang',
#  'Eurythmics&&Annie Lennox&&Dave Stewart',
#  'Billy Vera & The Beaters',
#  'Dutch Swing College Band',
#  'The Temptations',
#  'Balance',
#  'Neil Diamond',
#  'Ricardo Arjona',
#  'Culture Club',
#  'Throbbing Gristle',
#  'Steve Winwood',
#  'Kenny Rogers',
#  'Sly Fox',
#  'Bill Evans',
#  'Huey Lewis & The News',
#  'TOTO',
#  'The Cleaners From Venus',
#  'Cloven Hoof',
#  'Los Rebeldes',
#  'Udo Jürgens&&Jenny',
#  'One Way',
#  'Accept',
#  'Abstürzende Brieftauben',
#  'Culture Club',
#  'Herb Alpert',
#  'Brighton Rock',
#  'Pure Prairie League&&Craig Fuller&&Vince Gill&&John David Call&&Mike Reilly',
#  'José Alfredo Jimenez',
#  'Spandau Ballet',
#  'Amit Kumar&&R. D. Burman',
#  'Whitney Houston',
#  'Kenny Loggins',
#  'Prince',
#  'Van Halen',
#  'The Whispers',
#  'Kool & The Gang',
#  'Laura Branigan',
#  'Ricky Skaggs',
#  'Commodores',
#  'Survivor',
#  'Eric B. & Rakim',
#  'The Fools',
#  'Dr. Jeckyll & Mr. Hyde',
#  'Lucinda Williams',
#  'Redd Kross',
#  'Squeeze',
#  'Sam Bush',
#  'Johnny Hallyday',
#  'Pat Benatar',
#  'Nataural',
#  'Nataural',
#  'Fine Young Cannibals',
#  'Inner City',
#  'Crimson Glory',
#  'Babatunde Olatunji',
#  'John Cafferty & the Beaver Brown Band',
#  'Roky Erickson',
#  'Nobuo Uematsu',
#  'Nataural',
#  'Royal House',
#  'Limahl',
#  'The Prisoners',
#  'Foreigner',
#  'Running Wild',
#  'Take 6',
#  'Louisiana Red',
#  'Further Seems Forever',
#  'Beatriz Adriana',
#  'Psychic TV',
#  'Bananarama',
#  'My Life With The Thrill Kill Kult',
#  'Roy Ayers',
#  'Zebra',
#  'John Denver',
#  'KMFDM',
#  'Bessie Smith',
#  'Kanchan',
#  'Corey Hart',
#  'Sisters of Mercy',
#  'Big Black',
#  'UB40&&Chrissie Hynde',
#  'Doc Severinsen',
#  'Tony Rice&&Vassar Clements&&Jerry Douglas&&Todd Phillips&&Sam Bush&&Béla Fleck',
#  'Billy Joel',
#  'The Cult',
#  'Skinny Puppy',
#  'The Pogues',
#  'The Cleaners From Venus',
#  'Dolly Parton&&Kenny Rogers',
#  "Bob Fitts&&Integrity's Hosanna! Music",
#  'The Pointer Sisters',
#  "Ultramagnetic MC's",
#  'Gerry Mulligan',
#  'James Ingram',
#  'The Outfield',
#  'Elisa Fiorillo',
#  'Pat Benatar',
#  'Running Wild',
#  'Malcolm Arnold&&Vernon Handley&&Royal Philharmonic Orchestra',
#  'Imperiet',
#  'D.R.I.',
#  'Thompson Twins',
#  'Jackie DeShannon&&Michael McDonald',
#  'Bronski Beat',
#  'Martin Gore',
#  'Donna Summer',
#  'Strength In Numbers',
#  'Los Rebeldes',
#  'Captain Beefheart & His Magic Band',
#  'The Cleaners From Venus',
#  'The Pointer Sisters',
#  'Ton Steine Scherben',
#  'Leandro & Leonardo',
#  'Venom',
#  'Death In June',
#  'Stormwitch',
#  'The Cutlass Dance Band',
#  'Van Halen',
#  'Genesis',
#  'Nocera',
#  'Larry Gatlin & The Gatlin Brothers',
#  'Nataural',
#  'Donnie Iris',
#  'Brian Eno',
#  'Sandra De Sá',
#  'Throbbing Gristle',
#  'TOTO',
#  'The Real Roxanne',
#  'Minor Threat',
#  'Hans Zimmer',
#  'Zohar Argov',
#  'David Gates',
#  'Bob Mould',
#  'Arcadia',
#  'Brighton Rock',
#  'José José',
#  'Smokey Robinson',
#  'Gal Costa',
#  'Re-Flex',
#  'Jefferson Starship',
#  'Billy Joel',
#  'Rufus&&Chaka Khan',
#  'Steve Perry',
#  'Lisa Lisa & Cult Jam&&Full Force',
#  'Nataural',
#  'Aretha Franklin&&George Benson',
#  'Thompson Twins',
#  'Evelyn Thomas',
#  'Wham!',
#  'Kylie Minogue',
#  'Super Coper & Clarence Breakers',
#  'Skinny Puppy',
#  'Sweet Sensation',
#  'TOTO',
#  'Roger Hodgson',
#  'Bill Evans',
#  'Ratt',
#  'Zohar Argov',
#  'Johnny Clegg&&Savuka',
#  'A Flock Of Seagulls',
#  'Boston',
#  'Sad Lovers & Giants',
#  'Go West',
#  'Danny Elfman',
#  'Dexys Midnight Runners',
#  'Eddie Rabbitt',
#  'Stan Getz&&Luiz Bonfá',
#  'Rod Stewart',
#  'Curiosity Killed The Cat',
#  'The Gap Band',
#  'Alison Krauss & Union Station',
#  '2 LIVE CREW',
#  'Bill Evans',
#  'The J. Geils Band',
#  'John Denver',
#  'The Pogues',
#  'Brooklyn Funk Essentials',
#  'Foghat',
#  'Brad Fiedel',
#  'Ten City',
#  'Aldo Nova',
#  'Van Halen',
#  'Models',
#  'Zeca Pagodinho',
#  'Mexicanto',
#  'Olivier Messiaen&&Hans-Ola Ericsson',
#  'Frankie Smith',
#  'Lone Justice',
#  'Louise Tucker',
#  'Howard Jones',
#  'Luis Enrique',
#  'Gino Vannelli',
#  'The Darling Buds',
#  'Whitney Houston',
#  'Herb Alpert',
#  'KISS',
#  'Duran Duran',
#  'Little River Band',
#  'Benny Goodman Trio',
#  'Newcity Rockers',
#  'Steve Winwood',
#  'Isabel Pantoja',
#  'Robin Gibb',
#  'Red Hot Chili Peppers',
#  'Eddie Rabbitt',
#  'Billy Idol',
#  'Ana Gabriel',
#  'Change',
#  'Duncan Dhu',
#  'Genesis',
#  'Slime',
#  'The Gregg Allman Band',
#  'Rush',
#  'Kenny Loggins',
#  'The Cleaners From Venus',
#  'Tommy Shaw',
#  'Fiona',
#  'Breathless',
#  'Genesis',
#  'Nana Mouskouri',
#  'Laurie Anderson',
#  'LL COOL J',
#  'Al B. Sure!',
#  'Ann Wilson&&Robin Zander',
#  'Helix',
#  'Death In June',
#  'Rev. Gary Davis',
#  'ABBA',
#  'Sananda Maitreya',
#  'Harvey Reid',
#  'Clan of Xymox',
#  'Skinny Puppy',
#  'Jon Butcher Axis',
#  'Dolly Parton',
#  'Clarence Clemons&&Jackson Browne',
#  'Suzi Quatro',
#  'The Jesus and Mary Chain',
#  'Glenn Miller Orchestra',
#  'The Gun Club',
#  'The Whispers',
#  'Jennifer Warnes',
#  'Steve Perry',
#  'James Taylor',
#  'The Time',
#  'Harry Chapin',
#  'Pat Travers Band',
#  'Lulu Santos',
#  'Frankie Goes To Hollywood',
#  'Led Zeppelin',
#  'The Georgia Satellites',
#  'Bobby Hicks&&Doyle Lawson&&J.D. Crowe&&Jerry Douglas&&Todd Phillips&&Tony Rice',
#  'Missing Persons',
#  'Amy Grant',
#  'Palabra en Acción',
#  'Grover Washington, Jr.&&Bill Withers',
#  'Kenny Loggins',
#  'The Clash',
#  'Jagjit Singh',
#  'Fábio Jr.',
#  'Malcolm Arnold&&Mark Stephenson&&London Musici&&Karen Jones',
#  'Duke Ellington',
#  'A Flock Of Seagulls',
#  'John Barry',
#  'Ricky Skaggs',
#  'Tears For Fears&&Dave Bascombe',
#  'Brian Eno',
#  'Huey Lewis & The News',
#  'The Jacksons',
#  'Tom Petty and the Heartbreakers',
#  'Anthony Braxton&&Gino Robair',
#  'REO Speedwagon',
#  'Rocío Dúrcal',
#  'Venom',
#  'Minor Threat',
#  'Dave Van Ronk',
#  'Sting',
#  'Red Hot Chili Peppers',
#  'Jesse Johnson&&Sly Stone',
#  'Duran Duran',
#  'Lee Ritenour',
#  'Current 93',
#  'bel canto',
#  'Nobuo Uematsu',
#  'Joan Manuel Serrat',
#  'Slime',
#  'Skinny Puppy',
#  'John Mellencamp',
#  'Fleetwood Mac',
#  "Don Moen&&Integrity's Hosanna! Music",
#  'Roberta Flack&&Donny Hathaway',
#  'Saraya',
#  'Metal Church',
#  'Rod Stewart',
#  'Twennynine&&Lenny White',
#  'Miguel Cantilo',
#  'Bryan Adams',
#  'Skinny Puppy',
#  'Shana',
#  'Robbie Dupree',
#  'Blondie',
#  'Lou Rawls',
#  'Rev. Milton Brunson&&The Thompson Community Singers',
#  'Neil Diamond',
#  'The Prisoners',
#  'Momus',
#  'Cyndi Lauper',
#  'Momus',
#  'White Flag',
#  'Picture',
#  'Tina Turner',
#  'Bulletboys',
#  'The Cleaners From Venus',
#  'Chuck Brown and the Soul Searchers',
#  'Éric Serra',
#  'Mondo Rock',
#  'The Firm',
#  'Helloween',
#  'Sisters of Mercy',
#  'Brighton Rock',
#  'Valentín Clastrier',
#  'Sisters of Mercy',
#  'Running Wild',
#  'Bananarama',
#  'Chicago',
#  'Ofra Haza',
#  'Jorge Aragão',
#  'Nobuo Uematsu',
#  'James Brown',
#  'José José',
#  'David Pack',
#  'The Cramps',
#  'Leila Pinheiro',
#  'Brian Eno',
#  'El Fary',
#  'Psyche',
#  'Daniel Johnston',
#  'Tony Kinsey',
#  'The Buggles',
#  'Harvey Reid',
#  'Bill Monroe&&Del McCoury',
#  'The Communards&&Sarah Jane Morris',
#  'Earth, Wind & Fire',
#  'Stan Getz&&Charlie Byrd',
#  'INXS',
#  'Cher',
#  'John Coltrane&&Red Garland Trio',
#  'Paul McCartney',
#  'Timex Social Club',
#  'Tom Petty and the Heartbreakers&&Stevie Nicks',
#  'Haim Moshe',
#  'Anita Baker',
#  'Herb Alpert',
#  'Gal Costa',
#  'Kanchan',
#  'Royal House',
#  'Anthrax',
#  'Animotion',
#  'Billy Idol',
#  'Felt',
#  'Laura Branigan',
#  'Jonathan Ulysses&&Rosie Romero',
#  'Silvio Rodríguez',
#  'Dutch Swing College Band',
#  'Howard Jones',
#  'B.J. Thomas',
#  'Dan Fogelberg',
#  'Andy Clark',
#  'The Manhattans',
#  'The Time',
#  'James Ingram',
#  'Tina Turner',
#  'Jagjit Singh',
#  'Foreigner',
#  'Gloria Estefan And Miami Sound Machine',
#  'Cazuza',
#  'Squeeze',
#  'Stephen Bishop',
#  'Debbie Gibson',
#  'Danny Elfman',
#  'Brian Eno',
#  'Édith Piaf',
#  'Michael Morales',
#  'Supertramp',
#  'Minutemen',
#  'Crowded House',
#  'Gualberto Ibarreto',
#  'Billy Ocean',
#  'Tee Mac&&Majorie Barnes',
#  'Éric Serra',
#  'The Silencers',
#  'The Cars',
#  'The Prisoners',
#  'Anthrax',
#  'Beat Happening',
#  'Styx',
#  'Carlos Cano',
#  'Chuck Brown and the Soul Searchers',
#  'Paul McCartney',
#  'Cameo',
#  'EPMD',
#  'Minor Threat',
#  'Mai Tai',
#  'Michael Stanley Band',
#  'Tora Tora',
#  'Adrian Oblanca',
#  'Melissa Manchester',
#  'Randy Travis',
#  'Nataural',
#  'Talking Heads',
#  'Ton Steine Scherben',
#  'Joan Jett & the Blackhearts',
#  'David Grier',
#  'Amit Kumar&&Anuradha Paudwal',
#  'Rocío Dúrcal&&Juan Gabriel',
#  'Dire Straits',
#  'War',
#  'Bon Jovi',
#  'Smokey Robinson',
#  'Don Williams',
#  'Teddy Pendergrass',
#  'The Dream Syndicate',
#  'John Waite',
#  'INXS',
#  'Queen',
#  'Franke & The Knockouts',
#  'Pierre Favre',
#  'Torment',
#  'Device',
#  'Reba McEntire',
#  'Udo Jürgens',
#  'Grim Reaper',
#  'Éric Serra',
#  'U2',
#  'Starship',
#  'Elton John',
#  'Europe',
#  'Boaz Sharabi&&Shoshana Damari',
#  'Hubert Sumlin&&James Cotton',
#  "Guns N' Roses",
#  'Ricky Skaggs',
#  'Enya',
#  'Karl-Heinz Schäfer',
#  'Silvio Rodríguez',
#  'Fela Kuti',
#  'Cowboy Junkies',
#  'Skinny Puppy',
#  'Imperiet',
#  'Sheena Easton',
#  'Anthrax',
#  'Nataural',
#  'Survivor',
#  'Charley Patton',
#  'Lulu Santos',
#  'Jovelina Perola Negra',
#  'Eric B. & Rakim',
#  'Running Wild',
#  'Robbie Dupree',
#  'Abstürzende Brieftauben',
#  "Verckys & L'Orchestre Vévé&&L'Immortel Veve",
#  'Poco',
#  'Blackfoot',
#  'Kim Wilde',
#  'Los Rebeldes',
#  'Diamanda Galás',
#  'The Cramps',
#  'The Cramps',
#  'Ricky Skaggs',
#  'Kim Carnes',
#  'Eddie Money',
#  'Ricky Skaggs',
#  'Scandal&&Patty Smyth',
#  'Arthur Russell',
#  'Robert John',
#  'Leif Garrett',
#  'Seduction',
#  'Rich Mullins',
#  'José José',
#  'Cheech & Chong',
#  'Hubert Sumlin&&James Cotton',
#  'Patrice Rushen',
#  'Ali Thomson',
#  'Journey',
#  'Red Flag',
#  'Clan of Xymox',
#  'Léo Ferré',
#  'Big Joe Williams',
#  'Los Suaves',
#  'Anne Murray',
#  'Pedrinho Da Flor&&Monarco&&Argemiro',
#  'The Gap Band',
#  'John Stewart',
#  'Tony Kinsey',
#  'La Unión',
#  'The Human League',
#  'Midnight Star',
#  'Rappers Rapp Group',
#  'Les Rita Mitsouko',
#  'Andy Clark&&Manny Elias',
#  'Talking Heads',
#  'Michael Morales',
#  'Lionel Richie',
#  'Camilo Sesto',
#  'Richard Marx&&David Cole',
#  'Death In June',
#  'David Grisman',
#  'Throbbing Gristle',
#  'Elizabeth Cotten',
#  'Running Wild',
#  'Naked Eyes',
#  'Brooklyn Funk Essentials',
#  'Billy Preston&&Syreeta',
#  'Crimson Glory',
#  'The Payolas',
#  'Pet Shop Boys',
#  'Tina Turner',
#  'Kim Carnes',
#  'Dionne Warwick',
#  'Lionel Richie',
#  'The Escape Club',
#  'Meco',
#  'Kool & The Gang',
#  'Asha Bhosle',
#  'Young MC',
#  'Legião Urbana',
#  'Picture',
#  'Duncan Dhu',
#  'Four Tops',
#  'Joan Jett & the Blackhearts',
#  'Tesla',
#  'The Moody Blues',
#  'Martha Davis',
#  'Anup Jalota',
#  'Bruce Springsteen',
#  'Soundgarden',
#  'Trevor Rabin',
#  'Elvis Presley',
#  'Tony Kinsey',
#  'Luis Eduardo Aute',
#  'Tony Carey',
#  'Kurtis Blow',
#  'Ketama&&Toumani Diabaté&&Danny Thompson',
#  'Death In June',
#  'Bryan Adams',
#  'Nataural',
#  'Morris Day',
#  'KISS',
#  'Glenn Frey',
#  'Philip Glass&&Philip Glass Ensemble&&Michael Riesman',
#  'Raven',
#  'Madonna',
#  'The Alarm',
#  'Kim Carnes',
#  'Joey Scarbury',
#  'Sortilège',
#  'Zohar Argov',
#  'David Grisman',
#  'Mission Of Burma',
#  'Tuxedomoon',
#  'Further Seems Forever',
#  'Running Wild',
#  'Rosanne Cash',
#  'Culture Club',
#  'Trouble Funk',
#  'Rocío Jurado',
#  'Weird Al Yankovic',
#  'Stevie Wonder',
#  'YELLOW MAGIC ORCHESTRA',
#  'Charles Fox',
#  'Robbie Nevil',
#  'Vladimir Cosma',
#  'Luther Vandross',
#  'Malcolm Arnold&&Grimethorpe Colliery Band&&Elgar Howarth',
#  'Junkyard Band',
#  'Cinderella',
#  'Rub A Dub',
#  'Lulu Santos',
#  'Danny Elfman',
#  "Jack Starr's Burning Starr",
#  'Stan Getz&&Laurindo Almeida',
#  'Carlos Cano',
#  'Rick Springfield&&Randy Crawford',
#  'John Mellencamp',
#  'Shanice',
#  'DeBarge',
#  'George Michael',
#  'Fine Young Cannibals',
#  'Isabel Pantoja',
#  'Nana Mouskouri',
#  'Josie Cotton',
#  'Juliette Gréco',
#  'Corey Hart',
#  'The Cover Girls',
#  'Quarterflash',
#  'The Pogues',
#  'Phoebe Snow',
#  'Neneh Cherry',
#  'Skinny Puppy',
#  'Zohar Argov',
#  'The Darling Buds',
#  'Wipers',
#  'Nitzer Ebb',
#  'Twisted Sister',
#  'Lio',
#  'Running Wild',
#  'Babyface',
#  'Eurythmics&&Annie Lennox&&Dave Stewart',
#  'Herb Alpert',
#  'Kenny Loggins',
#  'Poco',
#  'Alabama',
#  'Steve Winwood',
#  'Magnum',
#  'Sammy Hagar',
#  'Shalamar',
#  'Barbra Streisand&&Kim Carnes',
#  'Galaxie 500',
#  'The Monkees',
#  'The Proclaimers',
#  'Gal Costa&&Roupa Nova',
#  'Michael Bolton',
#  'Christopher Cross',
#  'Sade',
#  'Daniel Johnston',
#  'Georges Delerue',
#  'Errobi',
#  'Nobuo Uematsu',
#  'Billy Ocean',
#  'Eric B. & Rakim',
#  'Climax Blues Band',
#  'Peter Cetera',
#  'Ton Steine Scherben',
#  'Def Leppard',
#  "Meli'sa Morgan",
#  'Big Country',
#  'Don McLean',
#  'Asha Bhosle',
#  'Aldo Nova',
#  'Daryl Runswick&&The KPM Orchestra',
#  'Kishore Kumar&&Amitabh Bachchan',
#  'Death In June',
#  'Def Leppard',
#  'Jeffrey Osborne',
#  'Michael Stanley Band',
#  'Bronski Beat',
#  'Hipsway',
#  'Prince',
#  'Loverboy',
#  'Cock Robin',
#  'Underworld',
#  'Barbra Streisand',
#  'Bryan Adams',
#  'José Guardiola',
#  'Beat Happening',
#  'Silvio Rodríguez',
#  'Enya',
#  'Pure Prairie League',
#  'Baden Powell',
#  'The Cramps',
#  'Doc Severinsen',
#  'Bruce Hornsby&&The Range',
#  'Ton Steine Scherben',
#  'Otis Spann',
#  'Rough Trade',
#  'Wham!',
#  'Suicide',
#  'Michael Jackson',
#  'Manos Hadjidakis&&Agnes Baltsa&&Athens Experimental Orchestra&&Stavros Xarhakos&&Kostas Papadopoulos',
#  'Divine Sounds',
#  'Night',
#  'INXS',
#  'Siouxsie and the Banshees',
#  'Artefact',
#  'Pierre Favre',
#  'Roedelius',
#  'Mickey Gilley',
#  'The Cleaners From Venus',
#  "Flamin' Groovies",
#  'Anuradha Paudwal&&Kumar Sanu',
#  'Divine Sounds',
#  'Champaign',
#  'Laura Branigan',
#  'Journey',
#  'Henry Lee Summer',
#  'Michael Bolton',
#  'Peaches & Herb',
#  'George Strait',
#  'Skinny Puppy',
#  'W.C. Handy&&Canadian Brass',
#  'Patti Austin',
#  'Kenny Rogers',
#  'Sheriff',
#  'Genesis',
#  'Ludwig Hirsch',
#  'Rick Astley',
#  'Whitesnake',
#  'Celtas Cortos',
#  'Dolly Parton',
#  'Pebbles',
#  'Yazoo',
#  'Nazia Hassan&&Zoheb Hassan',
#  'Aries Vigoth',
#  'Beverly Glenn-Copeland',
#  'Livingston Taylor',
#  'my bloody valentine',
#  'Paul Hindemith&&Jan Marcol',
#  'David Grisman',
#  'Milan Pilar',
#  'Red Rider',
#  'Richard Marx',
#  'The Bluegrass Album Band',
#  "Brother's Disco",
#  'Indigo Girls',
#  'Irene Cara',
#  'Westernhagen',
#  'Maurice Jarre',
#  'Chaka Khan',
#  'Basia',
#  'Queen',
#  'Peter Cetera',
#  'Eric B. & Rakim&&Chad Jay',
#  'Jeffrey Osborne',
#  'Ben E. King',
#  'Donna Summer',
#  ...]

# %%
spotify.tracks(['5wG3HvLhF6Y5KTGlK0IW3J','2Hh3ETdQKrmSI3QS0hme7g'])
# Out:
# {'tracks': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0iEtIxbK0KxaSlF7G42ZOp'},
#       'href': 'https://api.spotify.com/v1/artists/0iEtIxbK0KxaSlF7G42ZOp',
#       'id': '0iEtIxbK0KxaSlF7G42ZOp',
#       'name': 'Metro Boomin',
#       'type': 'artist',
#       'uri': 'spotify:artist:0iEtIxbK0KxaSlF7G42ZOp'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7txGsnDSqVMoRl6RQ9XyZP'},
#     'href': 'https://api.spotify.com/v1/albums/7txGsnDSqVMoRl6RQ9XyZP',
#     'id': '7txGsnDSqVMoRl6RQ9XyZP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c4fee55d7b51479627c31f89',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c4fee55d7b51479627c31f89',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c4fee55d7b51479627c31f89',
#       'width': 64}],
#     'name': 'HEROES & VILLAINS',
#     'release_date': '2022-12-02',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:7txGsnDSqVMoRl6RQ9XyZP'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0iEtIxbK0KxaSlF7G42ZOp'},
#      'href': 'https://api.spotify.com/v1/artists/0iEtIxbK0KxaSlF7G42ZOp',
#      'id': '0iEtIxbK0KxaSlF7G42ZOp',
#      'name': 'Metro Boomin',
#      'type': 'artist',
#      'uri': 'spotify:artist:0iEtIxbK0KxaSlF7G42ZOp'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#      'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#      'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#      'name': 'Travis Scott',
#      'type': 'artist',
#      'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/50co4Is1HCEo8bhOyUWKpn'},
#      'href': 'https://api.spotify.com/v1/artists/50co4Is1HCEo8bhOyUWKpn',
#      'id': '50co4Is1HCEo8bhOyUWKpn',
#      'name': 'Young Thug',
#      'type': 'artist',
#      'uri': 'spotify:artist:50co4Is1HCEo8bhOyUWKpn'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 194786,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUG12208787'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5wG3HvLhF6Y5KTGlK0IW3J'},
#    'href': 'https://api.spotify.com/v1/tracks/5wG3HvLhF6Y5KTGlK0IW3J',
#    'id': '5wG3HvLhF6Y5KTGlK0IW3J',
#    'is_local': False,
#    'name': 'Trance (with Travis Scott & Young Thug)',
#    'popularity': 86,
#    'preview_url': None,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:5wG3HvLhF6Y5KTGlK0IW3J'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0iEtIxbK0KxaSlF7G42ZOp'},
#       'href': 'https://api.spotify.com/v1/artists/0iEtIxbK0KxaSlF7G42ZOp',
#       'id': '0iEtIxbK0KxaSlF7G42ZOp',
#       'name': 'Metro Boomin',
#       'type': 'artist',
#       'uri': 'spotify:artist:0iEtIxbK0KxaSlF7G42ZOp'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7txGsnDSqVMoRl6RQ9XyZP'},
#     'href': 'https://api.spotify.com/v1/albums/7txGsnDSqVMoRl6RQ9XyZP',
#     'id': '7txGsnDSqVMoRl6RQ9XyZP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c4fee55d7b51479627c31f89',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c4fee55d7b51479627c31f89',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c4fee55d7b51479627c31f89',
#       'width': 64}],
#     'name': 'HEROES & VILLAINS',
#     'release_date': '2022-12-02',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:7txGsnDSqVMoRl6RQ9XyZP'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0iEtIxbK0KxaSlF7G42ZOp'},
#      'href': 'https://api.spotify.com/v1/artists/0iEtIxbK0KxaSlF7G42ZOp',
#      'id': '0iEtIxbK0KxaSlF7G42ZOp',
#      'name': 'Metro Boomin',
#      'type': 'artist',
#      'uri': 'spotify:artist:0iEtIxbK0KxaSlF7G42ZOp'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#      'href': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i',
#      'id': '1RyvyyTE3xzB2ZywiAwp0i',
#      'name': 'Future',
#      'type': 'artist',
#      'uri': 'spotify:artist:1RyvyyTE3xzB2ZywiAwp0i'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Gso3d4CscCijv0lmajZWs'},
#      'href': 'https://api.spotify.com/v1/artists/4Gso3d4CscCijv0lmajZWs',
#      'id': '4Gso3d4CscCijv0lmajZWs',
#      'name': 'Don Toliver',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Gso3d4CscCijv0lmajZWs'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 199920,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUG12208784'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2Hh3ETdQKrmSI3QS0hme7g'},
#    'href': 'https://api.spotify.com/v1/tracks/2Hh3ETdQKrmSI3QS0hme7g',
#    'id': '2Hh3ETdQKrmSI3QS0hme7g',
#    'is_local': False,
#    'name': 'Too Many Nights (feat. Don Toliver & with Future)',
#    'popularity': 86,
#    'preview_url': None,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:2Hh3ETdQKrmSI3QS0hme7g'}]}

# %%
albums[0:5]
# Out:
# ['Know-It-All (Deluxe)',
#  'The Genius of Esquivel',
#  'Love Someone',
#  'Cura',
#  'Juju on That Beat (TZ Anthem)']

# %%
release_date, release_date_precision = zip(*release_dates)

# %%
raw_data_df['album'] = albums
raw_data_df['release_type'] = release_types
raw_data_df['release_date'] = release_date
raw_data_df['release_date_precision'] = release_date_precision
raw_data_df['explicit'] = explicities
raw_data_df['popularities'] = popularities
raw_data_df['artists'] = artists_str_list

# %%
release_dates[0:5]
# Out:
# [('2015-11-13', 'day'),
#  ('2012-06-12', 'day'),
#  ('2018-09-07', 'day'),
#  ('2018-02-02', 'day'),
#  ('2016-09-30', 'day')]

# %%
raw_data_df.head()
# Out:
#                   track            artist  \
# 0         Walking Blues  Big Joe Williams
# 1  Suddenly Last Summer        The Motels
# 2             Sanctuary        Béla Fleck
# 3        The Wild Rover        The Pogues
# 4  In The Driver's Seat    John Schneider
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:1ZjN5X8LmUB67pWPgimW3B         0.509   0.277    6   -14.323
# 1  spotify:track:4fLIM0B1WwrLux9RdnMvze         0.716   0.753    2    -5.682
# 2  spotify:track:3DwlNfiCQSdj0GOxYkR9Rq         0.360   0.542    5   -13.885
# 3  spotify:track:6JyYNPLalPgGa7XnclF5FO         0.656   0.512    7   -11.872
# 4  spotify:track:6jJi8OXF5qaFdysB6sjWIT         0.642   0.889    2    -5.620
#
#    mode  speechiness  acousticness  ...  chorus_hit  sections  target  \
# 0     1       0.0495         0.827  ...    68.46530         7       0
# 1     1       0.0286         0.162  ...    57.71583        11       1
# 2     1       0.0339         0.368  ...    30.34574        17       0
# 3     1       0.0290         0.585  ...    50.97022         7       0
# 4     0       0.0494         0.375  ...    33.62053         7       1
#
#                                  album  release_type  release_date  \
# 0                        Walking Blues         album    1981-01-01
# 1                      Classic Masters         album    2002-01-01
# 2                                Drive         album    1988-01-01
# 3  Red Roses for Me (Expanded Edition)         album          1984
# 4                 The Dukes Of Hazzard         album          1978
#
#    release_date_precision  explicit  popularities  \
# 0                     day     False             0
# 1                     day     False            32
# 2                     day     False            13
# 3                    year     False            48
# 4                    year     False            22
#
#                                              artists
# 0                                   Big Joe Williams
# 1                                         The Motels
# 2  Béla Fleck&&Sam Bush&&Jerry Douglas&&Mark O'Co...
# 3                                         The Pogues
# 4                                     John Schneider
#
# [5 rows x 26 columns]

# %%
raw_data_df.to_csv('../data/built/track_features.csv', index=False)

# %%
req_series = raw_data_df.artists

# %%
raw_data_df.iloc[2].artists.split('&&')
# Out:
# ['Béla Fleck',
#  'Sam Bush',
#  'Jerry Douglas',
#  "Mark O'Connor",
#  'Tony Rice',
#  'Mark Schatz']

# %%
raw_data_df.artists
# Out:
# 0                                         Big Joe Williams
# 1                                               The Motels
# 2        Béla Fleck\nSam Bush\nJerry Douglas\nMark O'Co...
# 3                                               The Pogues
# 4                                           John Schneider
#                                ...
# 24693                                                Yolta
# 24694                                          Kodak Black
# 24695                                           Katy Perry
# 24696                Oscar Peterson\nRay Brown\nHerb Ellis
# 24697                                          Hans Zimmer
# Name: artists, Length: 24698, dtype: object

# %%
testing = raw_data_df.artists.apply(lambda x: len(x.split('\n')))

# %%
testing.max()
# Out:
# 23

# %%
testing.value_counts()
# Out:
# artists
# 1     20462
# 2      3001
# 3       796
# 4       251
# 5       103
# 6        48
# 7        17
# 9         9
# 8         3
# 14        1
# 18        1
# 10        1
# 17        1
# 16        1
# 11        1
# 23        1
# 13        1
# Name: count, dtype: int64
